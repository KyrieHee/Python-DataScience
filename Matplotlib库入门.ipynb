# %%
import matplotlib.pyplot as plt
#plt.plot()只有一个输入列表或数组时，参数被当作Y轴，X轴以索引自动生成
plt.plot([3,1,4,5,2])
plt.ylabel("Grade")
#plt.savefig()将输出图形存储为文件，默认PNG格式，可以通过dpi修改输出质量
plt.savefig('test', dpi=600)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([0,2,4,6,8],[3,1,4,5,2])
plt.ylabel("Grade")
plt.axis([-1, 10, 0, 6])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

a = np.arange(0.0, 5.0, 0.02)
plt.subplot(211)
plt.plot(a, f(a))

plt.subplot(2,1,2)
#plt.plot(a, np.cos(2*np.pi*t2), 'r--')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-bfa117494037> in <module>()
#      10
#      11 plt.subplot(2,1,2)
# ---> 12 plt.plot(a, np.cos(2*np.pi*t), 'r--')
#      13 plt.show()
#      14
#
# NameError: name 't' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.arange(10)
plt.plot(a, a*1.5, a, a*2.5, a, a*3.5, a, a*4.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'SimHei'
plt.plot([3,1,4,5,2])
plt.ylabel("纵轴（值）")

plt.savefig('test2', dpi=600)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-18-23d9859135ba> in <module>()
#       5 matplotlib.rcParams['font.family'] = 'SimHei'
#       6 plt.plot([3,1,4,5,2])
# ----> 7 plt.ylabel("纵轴（值）")
#       8
#       9 plt.savefig('test2', dpi=600)
#
# /Users/kyriehe/Library/Python/2.7/lib/python/site-packages/matplotlib/pyplot.pyc in ylabel(s, *args, **kwargs)
#    1575             work.
#    1576     """
# -> 1577     return gca().set_ylabel(s, *args, **kwargs)
#    1578
#    1579
#
# /Users/kyriehe/Library/Python/2.7/lib/python/site-packages/matplotlib/axes/_axes.pyc in set_ylabel(self, ylabel, fontdict, labelpad, **kwargs)
#     252         if labelpad is not None:
#     253             self.yaxis.labelpad = labelpad
# --> 254         return self.yaxis.set_label_text(ylabel, fontdict, **kwargs)
#     255
#     256     def _get_legend_handles(self, legend_handler_map=None):
#
# /Users/kyriehe/Library/Python/2.7/lib/python/site-packages/matplotlib/axis.pyc in set_label_text(self, label, fontdict, **kwargs)
#    1503         """
#    1504         self.isDefault_label = False
# -> 1505         self.label.set_text(label)
#    1506         if fontdict is not None:
#    1507             self.label.update(fontdict)
#
# /Users/kyriehe/Library/Python/2.7/lib/python/site-packages/matplotlib/text.pyc in set_text(self, s)
#    1210         ACCEPTS: string or anything printable with '%s' conversion.
#    1211         """
# -> 1212         self._text = '%s' % (s,)
#    1213         self.stale = True
#    1214
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe7 in position 0: ordinal not in range(128)
